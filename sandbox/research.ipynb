# %% [markdown]
# # Test `ClaudeAgent`

# %%
import os
import anthropic
from open_claude_agent import (
    ClaudeAgent,
    show_prompt,
    RESEARCH_AGENT_PROMPT,
    GENERAL_TOOL_USAGE_GUIDELINES
)

# Display how the prompts work together
print("=" * 100)
print("GENERAL TOOL USAGE GUIDELINES (Automatically included by ClaudeAgent)")
print("=" * 100)
show_prompt(GENERAL_TOOL_USAGE_GUIDELINES)

print("\n" + "=" * 100)
print("RESEARCH AGENT PROMPT (User-provided system_message)")
print("=" * 100)
show_prompt(RESEARCH_AGENT_PROMPT)

print("\n" + "=" * 100)
print("NOTE: When you create ClaudeAgent with system_message=RESEARCH_AGENT_PROMPT,")
print("the final system message will be: GENERAL_TOOL_USAGE_GUIDELINES + RESEARCH_AGENT_PROMPT")
print("=" * 100)
# Out:
# ====================================================================================================
# GENERAL TOOL USAGE GUIDELINES (Automatically included by ClaudeAgent)
# ====================================================================================================
# ╭──────────────────────────────────────────────────── Prompt ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │  ## Tool Usage Guidelines                                                                                       │
# │                                                                                                                 │
# │  **Web Search Tool:**                                                                                           │
# │  - Use for finding current information and diverse perspectives                                                 │
# │  - For simple queries: aim for 2-5 searches maximum                                                             │
# │  - For complex topics: may use up to 10-15 searches                                                             │
# │  - STOP searching once you have sufficient information to answer the question                                   │
# │  - After getting search results, critically evaluate their quality and relevance                                │
# │  - Add disclaimers if sources may not be accurate or comprehensive                                              │
# │                                                                                                                 │
# │  **Memory Tool:**                                                                                               │
# │  - Use to store important research findings for later reference                                                 │
# │  - Save key facts, sources, and summaries as you work                                                           │
# │  - Organize information in clearly named files (e.g., "research_quantum_computing.txt")                         │
# │  - Note: Memory tool operates in ./memories directory automatically                                             │
# │                                                                                                                 │
# │  **Text Editor Tool:**                                                                                          │
# │  - Use to read and edit project files                                                                           │
# │  - Can view, create, modify files throughout the project                                                        │
# │  - Includes automatic backups before modifications                                                              │
# │                                                                                                                 │
# │  **Bash Tool:**                                                                                                 │
# │  - Use for data processing, running tests, or system tasks                                                      │
# │  - Operates from current working directory                                                                      │
# │  - Always use relative paths (e.g., `./file.txt`, `cd project_dir`)                                             │
# │  - Never use absolute paths like `/memories` - these refer to system root, not your project                     │
# │  - The memories directory is managed by the memory tool - don't create it with bash                             │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ====================================================================================================
# RESEARCH AGENT PROMPT (User-provided system_message)
# ====================================================================================================
# ╭──────────────────────────────────────────────────── Prompt ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  You are a research assistant with access to web search, memory, text editor, and bash tools.                   │
# │                                                                                                                 │
# │  Your goal is to help users research topics by finding high-quality information, synthesizing it, and           │
# │  presenting clear summaries.                                                                                    │
# │                                                                                                                 │
# │  ## Research Process                                                                                            │
# │                                                                                                                 │
# │  1. **Plan First:** Before searching, think about:                                                              │
# │     - How complex is this query?                                                                                │
# │     - What sources would be most valuable?                                                                      │
# │     - How many tool calls will I likely need?                                                                   │
# │     - How will I know when I've found sufficient information?                                                   │
# │                                                                                                                 │
# │  2. **Search Strategically:**                                                                                   │
# │     - Start with broad searches to understand the landscape                                                     │
# │     - Follow up with specific searches for details                                                              │
# │     - Stop when you have enough quality information (don't over-search)                                         │
# │                                                                                                                 │
# │  3. **Evaluate Critically:**                                                                                    │
# │     - Not all search results are equally reliable                                                               │
# │     - Look for authoritative sources                                                                            │
# │     - Note when information may need verification                                                               │
# │                                                                                                                 │
# │  4. **Synthesize Clearly:**                                                                                     │
# │     - Organize findings logically                                                                               │
# │     - Cite sources when presenting information                                                                  │
# │     - Acknowledge uncertainty when appropriate                                                                  │
# │                                                                                                                 │
# │  ## Stopping Conditions                                                                                         │
# │                                                                                                                 │
# │  It's okay to stop searching if:                                                                                │
# │  - You've found sufficient high-quality information                                                             │
# │  - Additional searches are unlikely to add value                                                                │
# │  - You've reached your tool call budget for the query complexity                                                │
# │                                                                                                                 │
# │  Remember: Perfect is the enemy of good. Aim for helpful, accurate information rather than exhaustive           │
# │  perfection.                                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ====================================================================================================
# NOTE: When you create ClaudeAgent with system_message=RESEARCH_AGENT_PROMPT,
# the final system message will be: GENERAL_TOOL_USAGE_GUIDELINES + RESEARCH_AGENT_PROMPT
# ====================================================================================================

# %%
# Initialize Anthropic client
client = anthropic.Anthropic(api_key=os.environ.get("ANTHROPIC_API_KEY"))

# Create agent with all tools automatically configured
agent = ClaudeAgent(
    client=client,
    system_message=RESEARCH_AGENT_PROMPT,  # Optional: use research prompting
    max_web_searches=15  # Optional: increase for research tasks
)

print("✓ ClaudeAgent created with all tools!")
print("✓ Memory tool: ./memories directory (created automatically)")
print("✓ Bash & text editor: operate from current working directory")
print("✓ Web search: server-side (handled by Anthropic)")
print("\nReady to use! Try: agent.call('Your query here')")
# Out:
# ✓ ClaudeAgent created with all tools!
# ✓ Memory tool: ./memories directory (created automatically)
# ✓ Bash & text editor: operate from current working directory
# ✓ Web search: server-side (handled by Anthropic)
#
# Ready to use! Try: agent.call('Your query here')

# %%
messages = agent.call("Give me an overview of context engineering with popular blogs or papers?")
# Out:
# ╭─────────────────────────────────────────────────── 💬 Claude ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  💭 Thinking: I'll help you research context engineering, including popular blogs and papers on this topic.     │
# │  Let me start by checking my memory and then searching for relevant information.                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🔧 Tool Call: view                                                                                              │
# │    Path: /memories                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✓ Success: Directory listing for /memories                                                                      │
# │    Contents: []                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────── 💬 Claude ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  💭 Thinking: Now let me search for information about context engineering, including relevant papers and blog   │
# │  posts.                                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🌐 Server Tool Call: web_search                                                                                 │
# │    Query: context engineering AI                                                                                │
# │    (Executed server-side by Anthropic)                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🌐 Server Tool Call: web_search                                                                                 │
# │    Query: context engineering papers research                                                                   │
# │    (Executed server-side by Anthropic)                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🌐 Server Tool Call: web_search                                                                                 │
# │    Query: prompt engineering context window                                                                     │
# │    (Executed server-side by Anthropic)                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✓ Success: Server-side tool completed                                                                           │
# │    Preview: Now let me save this research to memory and provide you with a comprehensive overview.              │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🔧 Tool Call: create                                                                                            │
# │    Path: /memories/context_engineering_research.md                                                              │
# │    Params: {                                                                                                    │
# │       "file_text": "# Context Engineering Research\n\n## Key Definitions\n- **Context Engineering**: The        │
# │ practice of designing and building dynamic systems that provide the right information and tools, in the right   │
# │ format, at the right time, to give LLMs everything they need to accomplish a task\n- Broader than prompt        │
# │ engineering - focuses on managing the entire context window, not just writing better prompts\n- Includes:       │
# │ system prompts, memory (short/long-term), retrieval systems, tools, external data, conversation history\n\n##   │
# │ Major Papers\n1. **\"A Survey of Context Engineering for Large Language Models\"** (arXiv 2507.13334, July      │
# │ 2025)\n   - Comprehensive survey analyzing 1,300+ research papers\n   - Creates taxonomy: foundational          │
# │ components (retrieval, processing, management) + system implementations (RAG, memory, tools, multi-agent)\n   - │
# │ GitHub: Meirtz/Awesome-Context-Engineering\n\n2. **\"Context Engineering: Enhancing Large Language Model        │
# │ Performance\"** (ResearchGate, July 2025)\n   - Framework for systematic approach beyond prompt engineering\n   │
# │ - Covers RAG, tool integration, context window optimization\n\n## Popular Blogs & Articles\n\n### Major Company │
# │ Blogs\n1. **Anthropic** - \"Effective context engineering for AI agents\" (Sept 2025)\n   - Official company    │
# │ perspective on context engineering\n   - Discusses context as finite resource, strategies for management\n\n2.  │
# │ **LangChain** - \"The rise of context engineering\" (June 2025)\n   - Discusses shift from prompts to context\n │
# │ - Four strategies: write, select, compress, isolate\n\n3. **Philipp Schmid** - \"The New Skill in AI is Not     │
# │ Prompting, It's Context Engineering\" (June 2025)\n   - Highly influential blog post\n   - Agent failures are   │
# │ context failures, not model failures\n\n4. **Prompt Engineering Guide** - \"Context Engineering Guide\"         │
# │ (2025)\n   - Step-by-step practical guide\n   - Real examples with n8n workflows\n\n5. **DataCamp** - \"Context │
# │ Engineering: A Guide With Examples\" (July 2025)\n\n6. **LlamaIndex** - \"Context Engineering - What it is, and │
# │ techniques to consider\"\n\n7. **GitHub Blog** - \"How to build reliable AI workflows with agentic primitives   │
# │ and context engineering\"\n\n### Individual Thought Leaders\n- **Tobi Lutke** (Shopify CEO) - Credited with     │
# │ popularizing the term\n- **Andrej Karpathy** - \"Context engineering is the delicate art and science of filling │
# │ the context window with just the right information\"\n- **Dex Horthy** - \"12 Factor Agents\" framework\n\n##   │
# │ Key Concepts\n- **Context Window**: Limited \"working memory\" of LLMs (like RAM)\n- **Context Rot**:           │
# │ Performance degradation as context window fills\n- **Context Failures**: Tool overload, context clash,          │
# │ contextual distraction\n- **Strategies**: Summarization, compression, memory systems, RAG, tool selection\n\n## │
# │ Status\nResearch completed: Nov 1, 2025\nSources: 30+ articles, papers, and blogs reviewed\n"                   │
# │ }                                                                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✓ Success: Created file: /memories/context_engineering_research.md                                              │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────── 💬 Claude ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  # Overview of Context Engineering                                                                              │
# │                                                                                                                 │
# │  ## What is Context Engineering?                                                                                │
# │                                                                                                                 │
# │  Context Engineering is the discipline of designing and building dynamic systems that provides the right        │
# │  information and tools, in the right format, at the right time, to give a LLM everything it needs to            │
# │  accomplish a task. After a few years of prompt engineering being the focus of attention in applied AI, a new   │
# │  term has come to prominence: context engineering, with building with language models becoming less about       │
# │  finding the right words and phrases for your prompts, and more about answering the broader question of "what   │
# │  configuration of context is most likely to generate our model's desired behavior?"                             │
# │                                                                                                                 │
# │  Context engineering refers to the set of strategies for curating and maintaining the optimal set of tokens     │
# │  (information) during LLM inference, including all the other information that may land there outside of the     │
# │  prompts.                                                                                                       │
# │                                                                                                                 │
# │  ## Why Context Engineering Matters                                                                             │
# │                                                                                                                 │
# │  We are seeing that the main thing that determines whether an Agent succeeds or fails is the quality of the     │
# │  context you give it, and most agent failures are not model failures anymore, they are context failures. As AI  │
# │  systems have evolved from simple one-shot tasks to complex multi-turn agents operating over longer time        │
# │  horizons, managing the entire context state has become critical.                                               │
# │                                                                                                                 │
# │  ## Key Research Papers                                                                                         │
# │                                                                                                                 │
# │  ### 1. **"A Survey of Context Engineering for Large Language Models"** (July 2025)                             │
# │  **arXiv 2507.13334**                                                                                           │
# │                                                                                                                 │
# │  This is the most comprehensive academic treatment of context engineering to date. The survey introduces        │
# │  Context Engineering as a formal discipline that transcends simple prompt design to encompass the systematic    │
# │  optimization of information payloads for LLMs, presenting a comprehensive taxonomy decomposing Context         │
# │  Engineering into its foundational components and the sophisticated implementations that integrate them into    │
# │  intelligent systems.                                                                                           │
# │                                                                                                                 │
# │  The survey examines foundational components: context retrieval and generation, context processing and context  │
# │  management, then explores how these components are architecturally integrated to create sophisticated system   │
# │  implementations: retrieval-augmented generation (RAG), memory systems and tool-integrated reasoning, and       │
# │  multi-agent systems.                                                                                           │
# │                                                                                                                 │
# │  Through systematic analysis of over 1300 research papers, the survey establishes a technical roadmap for the   │
# │  field.                                                                                                         │
# │                                                                                                                 │
# │  **GitHub Repository**: The Awesome-Context-Engineering repository (Meirtz/Awesome-Context-Engineering)         │
# │  provides a comprehensive survey on Context Engineering: from prompt engineering to production-grade AI         │
# │  systems with hundreds of papers, frameworks, and implementation guides for LLMs and AI agents.                 │
# │                                                                                                                 │
# │  ### 2. **"Context Engineering: Enhancing Large Language Model Performance Through Comprehensive Contextual     │
# │  Management"** (July 2025)                                                                                      │
# │  **ResearchGate Publication**                                                                                   │
# │                                                                                                                 │
# │  This paper introduces "context engineering" as a systematic framework for improving large language model       │
# │  (LLM) performance, surpassing the limitations of traditional "prompt engineering," managing the full           │
# │  informational environment, including prompts, conversational history, external resources via                   │
# │  retrieval-augmented generation (RAG), tool integration, and context window optimization.                       │
# │                                                                                                                 │
# │  ## Popular Blogs and Industry Perspectives                                                                     │
# │                                                                                                                 │
# │  ### 1. **Anthropic - "Effective context engineering for AI agents"** (September 2025)                          │
# │                                                                                                                 │
# │  Anthropic's official blog post is one of the most authoritative sources. At Anthropic, they view context       │
# │  engineering as the natural progression of prompt engineering.                                                  │
# │                                                                                                                 │
# │  Context engineering is described as the art and science of curating what will go into the limited context      │
# │  window from that constantly evolving universe of possible information, with the curation phase being           │
# │  iterative and happening each time we decide what to pass to the model.                                         │
# │                                                                                                                 │
# │  Key insight: Given that LLMs are constrained by a finite attention budget, good context engineering means      │
# │  finding the smallest possible set of high-signal tokens that maximize the likelihood of some desired outcome.  │
# │                                                                                                                 │
# │  ### 2. **Philipp Schmid - "The New Skill in AI is Not Prompting, It's Context Engineering"** (June 2025)       │
# │                                                                                                                 │
# │  This highly influential blog post helped popularize the term. Tobi Lutke describes it as "the art of           │
# │  providing all the context for the task to be plausibly solvable by the LLM."                                   │
# │                                                                                                                 │
# │  The post emphasizes that with the rise of Agents it becomes more important what information we load into the   │
# │  "limited working memory," and the main thing that determines whether an Agents succeeds or fails is the        │
# │  quality of the context you give it.                                                                            │
# │                                                                                                                 │
# │  ### 3. **LangChain - "The rise of 'context engineering'"** (June 2025)                                         │
# │                                                                                                                 │
# │  Context engineering is building dynamic systems to provide the right information and tools in the right        │
# │  format such that the LLM can plausibly accomplish the task.                                                    │
# │                                                                                                                 │
# │  LLMs can mess up for two reasons: The underlying model just messed up, it isn't good enough, or the            │
# │  underlying model was not passed the appropriate context to make a good output, with more often than not        │
# │  (especially as the models get better) model mistakes being caused more by the second reason.                   │
# │                                                                                                                 │
# │  The blog outlines context engineering strategies including: Tool use, short term memory (creating a summary    │
# │  of the conversation and using that in the future), long term memory (fetching user preferences from previous   │
# │  conversations), prompt engineering (clearly enumerated instructions), and retrieval (fetching information      │
# │  dynamically and inserting it into the prompt).                                                                 │
# │                                                                                                                 │
# │  ### 4. **Prompt Engineering Guide - "Context Engineering Guide"**                                              │
# │                                                                                                                 │
# │  This resource provides practical, hands-on guidance. Context engineering is defined as the process of          │
# │  designing and optimizing instructions and relevant context for the LLMs and advanced AI models to perform      │
# │  their tasks effectively, encompassing not only text-based LLMs but also optimizing context for multimodal      │
# │  models.                                                                                                        │
# │                                                                                                                 │
# │  What you are trying to achieve in context engineering is optimizing the information you are providing in the   │
# │  context window of the LLM.                                                                                     │
# │                                                                                                                 │
# │  ### 5. **DataCamp - "Context Engineering: A Guide With Examples"** (July 2025)                                 │
# │                                                                                                                 │
# │  Instead of writing perfect prompts for individual requests, you create systems that gather relevant details    │
# │  from multiple sources and organize them within the model's context window, meaning your system pulls together  │
# │  conversation history, user data, external documents, and available tools, then formats them so the model can   │
# │  work with them.                                                                                                │
# │                                                                                                                 │
# │  ### 6. **LlamaIndex Blog - "Context Engineering - What it is, and techniques to consider"**                    │
# │                                                                                                                 │
# │  When in every industrial-strength LLM app, context engineering is the delicate art and science of filling the  │
# │  context window with just the right information for the next step, while "prompt engineering" focused on the    │
# │  art of providing the right instructions to an LLM at the forefront, "context engineering" puts a lot more      │
# │  focus on filling the context window of an LLM with the most relevant information, wherever that information    │
# │  may come from.                                                                                                 │
# │                                                                                                                 │
# │  ### 7. **LangChain - "Context Engineering for Agents"** (July 2025)                                            │
# │                                                                                                                 │
# │  Agents need context to perform tasks, with context engineering being the art and science of filling the        │
# │  context window with just the right information at each step of an agent's trajectory.                          │
# │                                                                                                                 │
# │  The post groups strategies into four buckets: write, select, compress, and isolate.                            │
# │                                                                                                                 │
# │  ## Key Thought Leaders                                                                                         │
# │                                                                                                                 │
# │  - **Andrej Karpathy** (formerly OpenAI): Described context engineering as "the delicate art and science of     │
# │  filling the context window with just the right information for the next step."                                 │
# │                                                                                                                 │
# │  - **Tobi Lutke** (Shopify CEO): Often credited with popularizing the term and framing it as providing          │
# │  complete context for task solvability                                                                          │
# │                                                                                                                 │
# │  - **Dex Horthy**: Created the "12 Factor Agents" framework that relates to context engineering principles      │
# │                                                                                                                 │
# │  ## Core Concepts                                                                                               │
# │                                                                                                                 │
# │  ### Context Window as Limited Resource                                                                         │
# │  The LLM context window is like RAM, serving as the model's working memory, and just like RAM, the LLM context  │
# │  window has limited capacity to handle various sources of context.                                              │
# │                                                                                                                 │
# │  ### Context Rot                                                                                                │
# │  Studies on needle-in-a-haystack style benchmarking have uncovered the concept of context rot: as the number    │
# │  of tokens in the context window increases, the model's ability to accurately recall information from that      │
# │  context decreases, with this characteristic emerging across all models.                                        │
# │                                                                                                                 │
# │  ### Common Context Failures                                                                                    │
# │  Context confusion occurs when models get distracted by irrelevant information and may use tools that don't     │
# │  match the task, with the solution being tool loadout management: use RAG techniques to select only the most    │
# │  relevant tools for each specific task, keeping selections under 30 tools.                                      │
# │                                                                                                                 │
# │  ## Practical Applications                                                                                      │
# │                                                                                                                 │
# │  Context engineering arguably started with retrieval augmented generation (RAG) systems, which were one of the  │
# │  first techniques that let you introduce LLMs to information that wasn't part of their original training data.  │
# │                                                                                                                 │
# │  Modern context engineering includes managing system prompts, tools, external data sources, conversation        │
# │  history, short-term and long-term memory systems, and determining what information to retrieve and when.       │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  This represents a major evolution in AI engineering, shifting focus from crafting perfect individual prompts   │
# │  to architecting entire information ecosystems that enable AI agents to perform reliably over extended          │
# │  interactions and complex tasks.                                                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
