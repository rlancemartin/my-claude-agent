# %% [markdown]
# # Test `ClaudeAgent`

# %%
import os
import anthropic
from open_claude_agent import (
    ClaudeAgent,
    show_prompt,
    RESEARCH_AGENT_PROMPT,
    GENERAL_TOOL_USAGE_GUIDELINES
)

# Display how the prompts work together
print("=" * 100)
print("GENERAL TOOL USAGE GUIDELINES (Automatically included by ClaudeAgent)")
print("=" * 100)
show_prompt(GENERAL_TOOL_USAGE_GUIDELINES)

print("\n" + "=" * 100)
print("RESEARCH AGENT PROMPT (User-provided system_message)")
print("=" * 100)
show_prompt(RESEARCH_AGENT_PROMPT)

print("\n" + "=" * 100)
print("NOTE: When you create ClaudeAgent with system_message=RESEARCH_AGENT_PROMPT,")
print("the final system message will be: GENERAL_TOOL_USAGE_GUIDELINES + RESEARCH_AGENT_PROMPT")
print("=" * 100)
# Out:
# ====================================================================================================
# GENERAL TOOL USAGE GUIDELINES (Automatically included by ClaudeAgent)
# ====================================================================================================
# ╭──────────────────────────────────────────────────── Prompt ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │  ## Tool Usage Guidelines                                                                                       │
# │                                                                                                                 │
# │  **Web Search Tool:**                                                                                           │
# │  - Use for finding current information and diverse perspectives                                                 │
# │  - For simple queries: aim for 2-5 searches maximum                                                             │
# │  - For complex topics: may use up to 10-15 searches                                                             │
# │  - STOP searching once you have sufficient information to answer the question                                   │
# │  - After getting search results, critically evaluate their quality and relevance                                │
# │  - Add disclaimers if sources may not be accurate or comprehensive                                              │
# │                                                                                                                 │
# │  **Memory Tool:**                                                                                               │
# │  - Use to store important research findings for later reference                                                 │
# │  - Save key facts, sources, and summaries as you work                                                           │
# │  - Organize information in clearly named files (e.g., "research_quantum_computing.txt")                         │
# │  - Note: Memory tool operates in ./memories directory automatically                                             │
# │                                                                                                                 │
# │  **Text Editor Tool:**                                                                                          │
# │  - Use to read and edit project files                                                                           │
# │  - Can view, create, modify files throughout the project                                                        │
# │  - Includes automatic backups before modifications                                                              │
# │                                                                                                                 │
# │  **Bash Tool:**                                                                                                 │
# │  - Use for data processing, running tests, or system tasks                                                      │
# │  - Operates from current working directory                                                                      │
# │  - Always use relative paths (e.g., `./file.txt`, `cd project_dir`)                                             │
# │  - Never use absolute paths like `/memories` - these refer to system root, not your project                     │
# │  - The memories directory is managed by the memory tool - don't create it with bash                             │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ====================================================================================================
# RESEARCH AGENT PROMPT (User-provided system_message)
# ====================================================================================================
# ╭──────────────────────────────────────────────────── Prompt ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  You are a research assistant with access to web search, memory, text editor, and bash tools.                   │
# │                                                                                                                 │
# │  Your goal is to help users research topics by finding high-quality information, synthesizing it, and           │
# │  presenting clear summaries.                                                                                    │
# │                                                                                                                 │
# │  ## Research Process                                                                                            │
# │                                                                                                                 │
# │  1. **Plan First:** Before searching, think about:                                                              │
# │     - How complex is this query?                                                                                │
# │     - What sources would be most valuable?                                                                      │
# │     - How many tool calls will I likely need?                                                                   │
# │     - How will I know when I've found sufficient information?                                                   │
# │                                                                                                                 │
# │  2. **Search Strategically:**                                                                                   │
# │     - Start with broad searches to understand the landscape                                                     │
# │     - Follow up with specific searches for details                                                              │
# │     - Stop when you have enough quality information (don't over-search)                                         │
# │                                                                                                                 │
# │  3. **Evaluate Critically:**                                                                                    │
# │     - Not all search results are equally reliable                                                               │
# │     - Look for authoritative sources                                                                            │
# │     - Note when information may need verification                                                               │
# │                                                                                                                 │
# │  4. **Synthesize Clearly:**                                                                                     │
# │     - Organize findings logically                                                                               │
# │     - Cite sources when presenting information                                                                  │
# │     - Acknowledge uncertainty when appropriate                                                                  │
# │                                                                                                                 │
# │  ## Stopping Conditions                                                                                         │
# │                                                                                                                 │
# │  It's okay to stop searching if:                                                                                │
# │  - You've found sufficient high-quality information                                                             │
# │  - Additional searches are unlikely to add value                                                                │
# │  - You've reached your tool call budget for the query complexity                                                │
# │                                                                                                                 │
# │  Remember: Perfect is the enemy of good. Aim for helpful, accurate information rather than exhaustive           │
# │  perfection.                                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ====================================================================================================
# NOTE: When you create ClaudeAgent with system_message=RESEARCH_AGENT_PROMPT,
# the final system message will be: GENERAL_TOOL_USAGE_GUIDELINES + RESEARCH_AGENT_PROMPT
# ====================================================================================================

# %%
# Initialize Anthropic client
client = anthropic.Anthropic(api_key=os.environ.get("ANTHROPIC_API_KEY"))

# Create agent with all tools automatically configured
agent = ClaudeAgent(
    client=client,
    system_message=RESEARCH_AGENT_PROMPT,  # Optional: use research prompting
    max_web_searches=15  # Optional: increase for research tasks
)

print("✓ ClaudeAgent created with all tools!")
print("✓ Memory tool: ./memories directory (created automatically)")
print("✓ Bash & text editor: operate from current working directory")
print("✓ Web search: server-side (handled by Anthropic)")
print("\nReady to use! Try: agent.call('Your query here')")
# Out:
# ✓ ClaudeAgent created with all tools!
# ✓ Memory tool: ./memories directory (created automatically)
# ✓ Bash & text editor: operate from current working directory
# ✓ Web search: server-side (handled by Anthropic)
#
# Ready to use! Try: agent.call('Your query here')

# %%
messages = agent.call("Give me an overview of context engineering with popular blogs or papers?")
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🔧 Tool Call: view                                                                                              │
# │    Path: /memories                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✓ Success: Directory listing for /memories                                                                      │
# │    Contents: []                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🌐 Server Tool Call: web_search                                                                                 │
# │    Query: context engineering AI LLM                                                                            │
# │    (Executed server-side by Anthropic)                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🌐 Server Tool Call: web_search                                                                                 │
# │    Query: context engineering papers research                                                                   │
# │    (Executed server-side by Anthropic)                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🌐 Server Tool Call: web_search                                                                                 │
# │    Query: prompt engineering context window                                                                     │
# │    (Executed server-side by Anthropic)                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✓ Success: Server-side tool completed                                                                           │
# │    Preview: Now let me save my findings and search for a few more specific papers:                              │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🔧 Tool Call: create                                                                                            │
# │    Path: /memories/context_engineering_research.md                                                              │
# │    Params: {                                                                                                    │
# │       "file_text": "# Context Engineering Research Overview\n\n## Definition\nContext Engineering is the        │
# │ systematic discipline of designing and building dynamic systems that provide the right information, tools, and  │
# │ instructions to LLMs in the right format at the right time to accomplish tasks effectively.\n\n## Key           │
# │ Concepts\n- **Beyond Prompt Engineering**: Context engineering transcends simple prompt design to encompass the │
# │ full optimization of information payloads for LLMs\n- **Dynamic Systems**: Not just static prompts, but systems │
# │ that dynamically assemble context for each interaction\n- **Context Window Management**: Treating the context   │
# │ window as a finite resource (like RAM) that needs careful curation\n\n## Major Papers\n\n### 1. \"A Survey of   │
# │ Context Engineering for Large Language Models\" (arXiv:2507.13334)\n- Published: July 2025\n- Authors: Lingrui  │
# │ Mei et al. (15 authors)\n- Analyzed over 1,400 research papers\n- Comprehensive taxonomy with:\n  -             │
# │ Foundational Components: context retrieval/generation, processing, management\n  - System Implementations: RAG, │
# │ memory systems, tool-integrated reasoning, multi-agent systems\n- Key finding: Asymmetry between models'        │
# │ context understanding vs. long-form generation capabilities\n\n### 2. \"Context Engineering: Enhancing Large    │
# │ Language Model Performance Through Comprehensive Contextual Management\"\n- Published: July 2025                │
# │ (ResearchGate)\n- Framework for managing full informational environment\n- Empirical evidence showing RAG and   │
# │ tool integration boost performance by 10-20% and 15% respectively\n\n## Popular Blog Posts & Articles\n\n###    │
# │ Industry Blogs\n\n1. **LangChain - \"The rise of context engineering\"** (June 2025)\n   - Defines context      │
# │ engineering as building dynamic systems\n   - Discusses LangGraph for controllable agent frameworks\n   -       │
# │ References Dex Horthy's \"12 Factor Agents\"\n   - Four strategies: write, select, compress, isolate\n\n2.      │
# │ **Anthropic - \"Effective context engineering for AI agents\"** (Recent)\n   - Context engineering as natural   │
# │ progression of prompt engineering\n   - Concept of \"context rot\" - model performance degrades with too many   │
# │ tokens\n   - \"Attention budget\" similar to human working memory\n   - Emphasis on finding smallest set of     │
# │ high-signal tokens\n\n3. **LlamaIndex - \"Context Engineering - What it is, and techniques to consider\"**\n    │
# │ - Context components: system prompt, user input, short-term memory, long-term memory, retrieved knowledge\n   - │
# │ Focus on filling context window with right information\n   - Practical implementation with LlamaCloud\n\n4.     │
# │ **Philipp Schmid - \"The New Skill in AI is Not Prompting, It's Context Engineering\"** (June 2025)\n   - Quote │
# │ from Tobi Lutke (Shopify CEO): \"the art of providing all the context for the task to be plausibly solvable\"\n │
# │ - Most agent failures are context failures, not model failures\n   - Dynamic, system-based approach vs. static  │
# │ prompts\n\n5. **DataCamp - \"Context Engineering: A Guide With Examples\"** (July 2025)\n   - RAG as early form │
# │ of context engineering\n   - Common failures: context decay, confusion, poisoning, distraction, clash\n   -     │
# │ Practical techniques and mitigation strategies\n\n6. **Prompt Engineering Guide - \"Context Engineering         │
# │ Guide\"**\n   - Broader definition encompassing multimodal models\n   - Concrete example with multi-agent deep  │
# │ research application\n   - Built with n8n workflow\n\n### Key Influencers\n- Andrej Karpathy: \"LLMs are like a │
# │ new kind of operating system - context window is like RAM\"\n- Tobi Lutke (Shopify CEO): Early endorsement and  │
# │ definition\n- Dex Horthy: \"12 Factor Agents\" framework\n\n## Core Components of Context\n\n1. **System        │
# │ Prompt/Instructions**: Core instructions, rules, persona\n2. **User Input**: Current query or command\n3.       │
# │ **Short-term Memory**: Recent conversation history\n4. **Long-term Memory**: Persistent facts, preferences,     │
# │ past interactions\n5. **Retrieved Knowledge**: RAG-based information from external sources\n6. **Tools**:       │
# │ Available functions and their descriptions\n7. **External Context**: Market data, business domain               │
# │ information\n\n## Common Context Engineering Strategies\n\n### 1. Write\n- Save context outside context window  │
# │ (scratchpad, notes)\n- Memory systems for persistence\n\n### 2. Select\n- RAG for retrieving relevant           │
# │ information\n- Tool selection (keep under 30 tools for 3x better accuracy)\n- Filtering noisy                   │
# │ information\n\n### 3. Compress\n- Summarization of long histories\n- Context compaction while preserving        │
# │ critical information\n\n### 4. Isolate\n- Sandboxing contexts\n- State objects with selective exposure\n\n##    │
# │ Context Failures\n\n1. **Context Rot/Decay**: Performance drops as tokens increase (even before hitting         │
# │ limits)\n2. **Context Poisoning**: Hallucinations enter the context\n3. **Context Distraction**: Irrelevant     │
# │ information overwhelms training\n4. **Context Confusion**: Superfluous context influences response\n5.          │
# │ **Context Clash**: Conflicting information in context\n6. **Contextual Drift**: Outdated context from earlier   │
# │ conversation\n\n## Research Gaps & Future Directions\n- Asymmetry in understanding vs. generation               │
# │ capabilities\n- Need for standardized methods\n- Ethical considerations\n- Scalability with multi-million token │
# │ windows\n\n## GitHub Resources\n- Meirtz/Awesome-Context-Engineering: Comprehensive survey with hundreds of     │
# │ papers\n- davidkimai/Context-Engineering: First-principles handbook\n\n## Status\nInitial research completed.   │
# │ Found major survey paper, industry blogs, and key frameworks.\n"                                                │
# │ }                                                                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✓ Success: Created file: /memories/context_engineering_research.md                                              │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🌐 Server Tool Call: web_search                                                                                 │
# │    Query: Dex Horthy 12 Factor Agents                                                                           │
# │    (Executed server-side by Anthropic)                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🌐 Server Tool Call: web_search                                                                                 │
# │    Query: Self-RAG context engineering paper                                                                    │
# │    (Executed server-side by Anthropic)                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✓ Success: Server-side tool completed                                                                           │
# │    Preview: Perfect! I now have comprehensive information. Let me update my memory and create a final summary   │
# │ for the user:                                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🔧 Tool Call: str_replace                                                                                       │
# │    Path: /memories/context_engineering_research.md                                                              │
# │    Params: {                                                                                                    │
# │       "old_str": "## Status\nInitial research completed. Found major survey paper, industry blogs, and key      │
# │ frameworks.",                                                                                                   │
# │       "new_str": "## Additional Key Papers\n\n### 3. \"Self-RAG: Learning to Retrieve, Generate, and Critique   │
# │ through Self-Reflection\" (arXiv:2310.11511)\n- Published: October 2023\n- Authors: Akari Asai et al.\n-        │
# │ Framework for adaptive retrieval with self-reflection tokens\n- LLM decides when to retrieve and evaluates      │
# │ relevance\n- Outperforms ChatGPT on QA and reasoning tasks\n\n## Dex Horthy's \"12-Factor                       │
# │ Agents\"\n\n**Repository**: https://github.com/humanlayer/12-factor-agents\n- Created: April 2025, presented at │
# │ AI Engineer World's Fair\n- Inspired by Heroku's 12-Factor App methodology\n- Based on interviews with 100+     │
# │ production AI implementations\n- Key finding: Most successful \"AI agents\" aren't purely agentic - they're     │
# │ well-engineered software with LLM capabilities at key points\n\n**12 Key Principles**:\n1. Own your prompts     │
# │ (treat as code, version, test)\n2. Own your control flow (understand agent decision-making)\n3. Small, focused  │
# │ agents (microservices approach)\n4. Tools are structured outputs (JSON contracts, not voodoo)\n5. Stateless     │
# │ reducer design (functional programming)\n6. Own your context building\n7. Separate business from execution      │
# │ state\n8. Contact humans as first-class operations\n9. Meet users where they are (multi-channel)\n10. Explicit  │
# │ error handling\n11. JSON extraction as foundation\n12. Find the bleeding edge\n\n**Impact**: \n- Top of Hacker  │
# │ News\n- 10k+ GitHub stars\n- Referenced by LangChain, LlamaIndex, Anthropic\n\n## Context Rot & Research from   │
# │ Chroma\n\n**Paper**: \"Context Rot\" research by Jeff Huber/Chroma team\n- Model accuracy declines as context   │
# │ window fills (even before hitting limits)\n- Performance can drop significantly beyond 32,000 tokens\n-         │
# │ Related: Databricks paper (August 2024) on context confusion/distraction\n\n## Major Industry                   │
# │ Perspectives\n\n### Latent Space Podcast with Jeff Huber (Chroma)\n- \"RAG is Dead, Context Engineering is      │
# │ King\" (August 2025)\n- Context engineering = figuring out what should be in context window\n- Inner loop: what │
# │ goes in this time\n- Outer loop: how to get better at filling it over time\n\n### Towards Data Science\n-       │
# │ Context engineering as successor to naive RAG\n- RAG 2.0, agentic retrieval, context engineering are            │
# │ evolution\n- Naive RAG implementation largely dead, but descendants thriving\n\n## Status\nResearch completed.  │
# │ Comprehensive overview with papers, blogs, frameworks, and key figures identified."                             │
# │ }                                                                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✓ Success: Replaced text in file: /memories/context_engineering_research.md                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────── 💬 Claude ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ## Overview of Context Engineering                                                                             │
# │                                                                                                                 │
# │  Context engineering is an emerging discipline in AI that represents the evolution beyond simple prompt         │
# │  engineering. Let me give you a comprehensive overview with key papers and blogs.                               │
# │                                                                                                                 │
# │  ### What is Context Engineering?                                                                               │
# │                                                                                                                 │
# │  Context engineering is building dynamic systems to provide the right information and tools in the right        │
# │  format such that the LLM can plausibly accomplish the task. Context Engineering is the discipline of           │
# │  designing and building dynamic systems that provides the right information and tools, in the right format, at  │
# │  the right time, to give a LLM everything it needs to accomplish a task.                                        │
# │                                                                                                                 │
# │  Unlike prompt engineering, which focuses on crafting individual prompts, context engineering is about          │
# │  architecting the entire information environment for AI systems. As Andrej Karpathy puts it, LLMs are like a    │
# │  new kind of operating system. The LLM is like the CPU and its context window is like the RAM, serving as the   │
# │  model's working memory.                                                                                        │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Major Research Paper                                                                                        │
# │                                                                                                                 │
# │  ### **"A Survey of Context Engineering for Large Language Models"** (arXiv:2507.13334)                         │
# │                                                                                                                 │
# │  This is the definitive academic resource on context engineering:                                               │
# │                                                                                                                 │
# │  - **Published**: July 2025                                                                                     │
# │  - **Authors**: Lingrui Mei and 14 co-authors                                                                   │
# │  - **Scope**: Through this systematic analysis of over 1400 research papers, our survey not only establishes a  │
# │  technical roadmap for the field                                                                                │
# │                                                                                                                 │
# │  **Key Framework**: We first examine the foundational components: context retrieval and generation, context     │
# │  processing and context management. We then explore how these components are architecturally integrated to      │
# │  create sophisticated system implementations: retrieval-augmented generation (RAG), memory systems and          │
# │  tool-integrated reasoning, and multi-agent systems.                                                            │
# │                                                                                                                 │
# │  **Link**: https://arxiv.org/abs/2507.13334                                                                     │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Essential Blog Posts & Articles                                                                             │
# │                                                                                                                 │
# │  ### 1. **LangChain - "The rise of context engineering"** (June 2025)                                           │
# │  I would also argue that prompt engineering is a subset of context engineering. Even if you have all the        │
# │  context, how you assemble it in the prompt still absolutely matters.                                           │
# │                                                                                                                 │
# │  Key strategies discussed:                                                                                      │
# │  - **Write**: Save context outside context window for later use                                                 │
# │  - **Select**: RAG for retrieving relevant information                                                          │
# │  - **Compress**: Summarize long histories                                                                       │
# │  - **Isolate**: Sandboxing and state objects                                                                    │
# │                                                                                                                 │
# │  **Link**: https://blog.langchain.com/the-rise-of-context-engineering/                                          │
# │                                                                                                                 │
# │  ### 2. **Anthropic - "Effective context engineering for AI agents"**                                           │
# │  At Anthropic, we view context engineering as the natural progression of prompt engineering.                    │
# │                                                                                                                 │
# │  Important concept: Studies on needle-in-a-haystack style benchmarking have uncovered the concept of context    │
# │  rot: as the number of tokens in the context window increases, the model's ability to accurately recall         │
# │  information from that context decreases.                                                                       │
# │                                                                                                                 │
# │  **Link**: https://www.anthropic.com/engineering/effective-context-engineering-for-ai-agents                    │
# │                                                                                                                 │
# │  ### 3. **Philipp Schmid - "The New Skill in AI is Not Prompting, It's Context Engineering"** (June 2025)       │
# │  We are seeing that the main thing that determines whether an Agents succeeds or fails is the quality of the    │
# │  context you give it. Most agent failures are not model failures anyemore, they are context failures.           │
# │                                                                                                                 │
# │  **Link**: https://www.philschmid.de/context-engineering                                                        │
# │                                                                                                                 │
# │  ### 4. **LlamaIndex - "Context Engineering - What it is, and techniques to consider"**                         │
# │  While the term "prompt engineering" focused on the art of providing the right instructions to an LLM at the    │
# │  forefront, although these two terms may seem very similar, "context engineering" puts a lot more focus on      │
# │  filling the context window of an LLM with the most relevant information, wherever that information may come    │
# │  from.                                                                                                          │
# │                                                                                                                 │
# │  **Link**: https://www.llamaindex.ai/blog/context-engineering-what-it-is-and-techniques-to-consider             │
# │                                                                                                                 │
# │  ### 5. **Prompt Engineering Guide - "Context Engineering Guide"**                                              │
# │  Includes practical examples and concrete implementation with n8n workflow for multi-agent systems.             │
# │                                                                                                                 │
# │  **Link**: https://www.promptingguide.ai/guides/context-engineering-guide                                       │
# │                                                                                                                 │
# │  ### 6. **DataCamp - "Context Engineering: A Guide With Examples"** (July 2025)                                 │
# │  Context engineering arguably started with retrieval augmented generation (RAG) systems. RAG was one of the     │
# │  first techniques that let you introduce LLMs to information that wasn't part of their original training data.  │
# │                                                                                                                 │
# │  **Link**: https://www.datacamp.com/blog/context-engineering                                                    │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Important Framework: Dex Horthy's "12-Factor Agents"                                                        │
# │                                                                                                                 │
# │  What are the principles we can use to build LLM-powered software that is actually good enough to put in the    │
# │  hands of production customers?                                                                                 │
# │                                                                                                                 │
# │  **Created**: April 2025                                                                                        │
# │  **GitHub**: https://github.com/humanlayer/12-factor-agents                                                     │
# │  **Impact**: The approach struck a nerve in the developer community – the open-source guide quickly climbed to  │
# │  the front page of Hacker News, garnered thousands of GitHub stars                                              │
# │                                                                                                                 │
# │  Key insight: Most of the products out there billing themselves as "AI Agents" are not all that agentic. A lot  │
# │  of them are mostly deterministic code, with LLM steps sprinkled in at just the right points to make the        │
# │  experience truly magical.                                                                                      │
# │                                                                                                                 │
# │  The framework covers principles like owning your prompts, owning control flow, building small focused agents,  │
# │  and treating tools as structured outputs.                                                                      │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Key Research Papers                                                                                         │
# │                                                                                                                 │
# │  ### **Self-RAG** (arXiv:2310.11511, October 2023)                                                              │
# │  We introduce a new framework called Self-Reflective Retrieval-Augmented Generation (Self-RAG) that enhances    │
# │  an LM's quality and factuality through retrieval and self-reflection. Our framework trains a single arbitrary  │
# │  LM that adaptively retrieves passages on-demand, and generates and reflects on retrieved passages and its own  │
# │  generations using special tokens, called reflection tokens.                                                    │
# │                                                                                                                 │
# │  **GitHub**: https://github.com/AkariAsai/self-rag                                                              │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Context Engineering Components                                                                              │
# │                                                                                                                 │
# │  The context for an AI system typically includes:                                                               │
# │                                                                                                                 │
# │  1. **System Prompt**: Instructions, rules, persona                                                             │
# │  2. **User Input**: Current query                                                                               │
# │  3. **Short-term Memory**: Recent conversation history                                                          │
# │  4. **Long-term Memory**: Persistent facts and preferences                                                      │
# │  5. **Retrieved Knowledge**: RAG-based external information                                                     │
# │  6. **Tools**: Available functions and descriptions                                                             │
# │  7. **External Context**: Business domain, market data                                                          │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Common Context Failures                                                                                     │
# │                                                                                                                 │
# │  First, there's context decay. Models get confused by long, messy contexts, leading to hallucinations and       │
# │  misguided answers. A recent study found that model correctness can start dropping significantly once the       │
# │  context exceeds 32,000 tokens, long before the advertised 2 million-token limits are reached                   │
# │                                                                                                                 │
# │  Other failures include:                                                                                        │
# │  - **Context Poisoning**: Hallucinations enter the context                                                      │
# │  - **Context Distraction**: Irrelevant information overwhelms the model                                         │
# │  - **Context Confusion**: Superfluous information influences responses                                          │
# │  - **Context Clash**: Conflicting information in context                                                        │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Additional Resources                                                                                        │
# │                                                                                                                 │
# │  **GitHub Repositories**:                                                                                       │
# │  - Meirtz/Awesome-Context-Engineering: Comprehensive collection of papers and resources                         │
# │  - davidkimai/Context-Engineering: First-principles handbook                                                    │
# │                                                                                                                 │
# │  **Industry Perspectives**:                                                                                     │
# │  - Latent Space podcast with Jeff Huber (Chroma): "RAG is Dead, Context Engineering is King"                    │
# │  - Multiple Towards Data Science articles on the evolution from RAG to context engineering                      │
# │                                                                                                                 │
# │  This represents a fundamental shift in how we think about building AI systems—from crafting perfect prompts    │
# │  to architecting information ecosystems that enable AI to reason and act effectively.                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
